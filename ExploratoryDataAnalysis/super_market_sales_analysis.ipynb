# %%
import pandas as pd

# %%
# import data
salesData = pd.read_csv(r"dataset/supermarket_sales.csv")
salesData
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200     80.22
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
salesData.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200     80.22
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880   489.048
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1  03-08-2019  10:29         Cash   76.40                 4.761905
# ...

# %%
salesData.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                       object
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
# a=[]
# for ele in salesData['Total']:
#     if ele.find('"') != -1:
#         a.append(ele.replace('"',''))
#     else:
#         a.append(ele)
# salesData['Total'] = a

# %%
# total_list = []
# for x in salesData['Total']:
#     y=x.replace('"','')
#     total_list.append(y)
# salesData['Total'] = total_list

# %%
salesData['Total'] = salesData['Total'].apply(lambda x:x.replace('"',''))

# %%
salesData.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                       object
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
salesData['Total']= salesData['Total'].astype('float64')

# %%
salesData['Date'] = salesData['Date'].astype('datetime64')

# %%
salesData.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
salesData.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#1 Total number of customers visited?
totalCustomer = salesData['Invoice ID'].shape[0]
totalCustomer
# Out:
# 1000

# %%
#2 Most visited branch?
branchMode = salesData['Branch'].mode()[0]
branchMode
# Out:
# 'A'

# %%
#3  City vs customer analysis? -average spend
filterData = salesData.groupby('City').mean()['Total']
filterData
# Out:
# City
# Mandalay     319.872506
# Naypyitaw    337.099715
# Yangon       312.354031
# Name: Total, dtype: float64

# %%
#4 Customer ratio based on customer type?
dataFilter = salesData.groupby(['Customer type']).count()['Invoice ID']/salesData.shape[0]
print(dataFilter)
# Out:
# Customer type
# Member    0.501
# Normal    0.499
# Name: Invoice ID, dtype: float64

# %%
#5 Most sold product line? general analysis
mostSoldProduct = salesData.groupby('Product line').sum()['Quantity']
maxVal = mostSoldProduct.idxmax()
maxVal
# Out:
# 'Electronic accessories'

# %%
#6 Costliest product in the shop?
costliestProduct = salesData.groupby('Product line').max()['Unit price']
print(costliestProduct)
costliestItem = costliestProduct.idxmax()
costliestItem
# Out:
# Product line
# Electronic accessories    99.73
# Fashion accessories       99.89
# Food and beverages        99.79
# Health and beauty         99.96
# Home and lifestyle        99.92
# Sports and travel         99.96
# Name: Unit price, dtype: float64
# 'Health and beauty'

# %%
#7 Total gross income?(profit)
profit = salesData['Total'].sum()
profit
# Out:
# 322966.749

# %%
#8 Total gross income per branch?
profitByBranch = salesData.groupby('Branch').sum()['Total']
profitByBranch
# Out:
# Branch
# A    106200.3705
# B    106197.6720
# C    110568.7065
# Name: Total, dtype: float64

# %%
#9 Total gross income by customer Type?
profitByCustomerType = salesData.groupby('Customer type').sum()['Total']
profitByCustomerType
# Out:
# Customer type
# Member    164223.444
# Normal    158743.305
# Name: Total, dtype: float64

# %%
#10 Total gross income by Payment type ?
profitByPaymentType = salesData.groupby('Payment').sum()['Total']
profitByPaymentType
# Out:
# Payment
# Cash           112206.570
# Credit card    100767.072
# Ewallet        109993.107
# Name: Total, dtype: float64

# %%
#11 Total Margin?
totalGrossMarginePercentage = salesData['gross margin percentage'].sum()
totalGrossMarginePercentage
# Out:
# 4761.904762

# %%
#12 Customer satisfaction analysis based on rating

def satisfaction(rating):
    if rating >= 9:
        rat = 'Highly satisfied'
    elif rating >= 6:
        rat = 'Satisfied'
    else:
        rat = 'disatisfied'
    return rat

# %%
salesData['Satisfaction'] = salesData['Rating'].map(lambda x:satisfaction(x))
salesData.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
ratingAnalysis = salesData['Satisfaction'].value_counts()
ratingAnalysis
# Out:
# Satisfied           519
# disatisfied         315
# Highly satisfied    166
# Name: Satisfaction, dtype: int64

# %%
ratingAnalysis = salesData[['City','Satisfaction']].value_counts()
ratingAnalysis
# Out:
# City       Satisfaction
# Mandalay   Satisfied           176
# Yangon     Satisfied           172
# Naypyitaw  Satisfied           171
# Mandalay   disatisfied         112
# Yangon     disatisfied         106
# Naypyitaw  disatisfied          97
# Yangon     Highly satisfied     62
# Naypyitaw  Highly satisfied     60
# Mandalay   Highly satisfied     44
# dtype: int64

# %%
ratingAnalysis = salesData['Rating'].value_counts()
ratingAnalysis
# Out:
# 6.0     26
# 6.6     24
# 9.5     22
# 4.2     22
# 6.2     21
#         ..
# 4.0     11
# 8.3     11
# 5.3     11
# 4.6      8
# 10.0     5
# Name: Rating, Length: 61, dtype: int64

# %%
salesData['actualDate'] = salesData['Date'].astype('datetime64')

# %%
salesData['month'] = salesData['actualDate'].apply(lambda x: x.strftime("%B"))

# %%
# Monthly income, monthly foot fall - this can be useful for identifying any seasonality
salesPerMonth = salesData.groupby('month').sum()['gross income'].sort_values()
salesPerMonth
# Out:
# month
# February    4629.494
# March       5212.167
# January     5537.708
# Name: gross income, dtype: float64

# %%
# Hour is extrating from Time
salesData['hours'] = salesData['Time'].astype('datetime64').apply(lambda x : x.strftime("%H"))
salesData.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  ...  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  ...
# 1  Electronic accessories       15.28         5   3.8200   80.2200  ...
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  ...
# 3       Health and beauty       58.22         8  23.2880  489.0480  ...
# 4       Sports and travel       86.31         7  30.2085  634.3785  ...
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
# Hour Based - rush hours? in hour basis
hourBased = salesData.groupby('hours').sum()['gross income'].sort_values()
hourBased
# Out:
# hours
# 20    1093.7870
# 17    1164.0580
# 16    1201.2535
# 18    1239.5400
# 12    1241.2325
# 11    1446.5395
# 14    1468.0190
# 15    1484.7385
# 10    1496.2610
# 13    1653.4870
# 19    1890.4530
# Name: gross income, dtype: float64
